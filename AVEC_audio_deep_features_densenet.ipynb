# %%
import tensorflow as tf
# import cv2 as cv
import os
import numpy as np
import glob
# # from random import shuffle
from google.colab import drive
import matplotlib.pyplot as plt
import csv
import re
import json
import math
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.layers import Embedding,Input
# from keras.models import Model
# from keras.optimizers import Adam
# from keras.layers import Bidirectional,LSTM,GlobalMaxPool1D,Dense
# from tensorflow.contrib import rnn
from sklearn.utils import shuffle

import tensorflow_hub as hub

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def send(t_data,e_data):
    temp=[]
    ret_data=[]
    for ind,r in enumerate(e_data):
      if ind>0:
        x=r[2:]
  #         b=x.pop(0)
  # #         print(a,b)
  #       print(x)
        xx=list(map(np.float32,x))
#         print(len(xx))
        temp.append(xx)
  # #     print(len(temp))
# #     m.append(len(temp))
    for ind , r  in enumerate(t_data):
#         print(type(r[0]),r[0],r)
        if(ind>0):
            start_time,stop_time=math.floor(float(r[0])),math.floor(float(r[1]))
    #             print(r[0],r[1])
            if(stop_time<len(temp) and (stop_time-start_time)<100):
                for i in range(int(start_time),int(stop_time)):
#                     print(i)
                    ret_data.append(temp[i])
    m.append(len(ret_data))
    return ret_data

# %%
target_densenet=[]
m=[]
densenet_data=[]
emb_dim=1415
pth=["/content/drive/My Drive/audio_deep_features/*densenet*.csv"]
for filename in glob.glob(pth[0]):#CHANGE PATH
#   print(filename)
    tmp=[]
    if 'test' not in filename:
        print(filename)
        target_densenet.append(filename.split("/")[-1].split(".")[0][:-12])
#         print(target)
        with open(filename,"rt") as f:
            b_data=csv.reader(f)
            for filename1 in glob.glob("/content/drive/My Drive/AVEC_trans/*"+target_densenet[-1]+"*.csv"):
                print(filename1)
                with open(filename1,"rt") as f1:
                    t_data=csv.reader(f1)
                    tmp=send(t_data,b_data)
#                 ege_data.append(tmp)
                    mf=np.asarray(tmp)
                    print(mf.shape)
                    a = np.zeros((emb_dim-mf.shape[0],1920))
                    mf=np.vstack((a,mf))
#                 m.append(mf.shape[0])
                    densenet_data.append(mf)
        print(mf.shape)
# Out:
# /content/drive/My Drive/audio_deep_features/training_001_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_001_Transcript.csv
# (221, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_002_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_002_Transcript.csv
# (622, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_003_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_003_Transcript.csv
# (364, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_004_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_004_Transcript.csv
# (1148, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_005_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_005_Transcript.csv
# (971, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_006_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_006_Transcript.csv
# (371, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_007_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_007_Transcript.csv
# (193, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_008_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_008_Transcript.csv
# (298, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_009_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_009_Transcript.csv
# (214, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_010_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_010_Transcript.csv
# (343, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_011_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_011_Transcript.csv
# (271, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_012_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_012_Transcript.csv
# (1090, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_013_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_013_Transcript.csv
# (522, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_014_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_014_Transcript.csv
# (225, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_015_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_015_Transcript.csv
# (251, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_016_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_016_Transcript.csv
# (241, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_017_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_017_Transcript.csv
# (543, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_018_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_018_Transcript.csv
# (418, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_019_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_019_Transcript.csv
# (275, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_020_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_020_Transcript.csv
# (525, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_021_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_021_Transcript.csv
# (197, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_022_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_022_Transcript.csv
# (278, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_023_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_023_Transcript.csv
# (678, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_024_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_024_Transcript.csv
# (366, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_025_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_025_Transcript.csv
# (187, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_026_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_026_Transcript.csv
# (366, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_027_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_027_Transcript.csv
# (452, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_028_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_028_Transcript.csv
# (452, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_029_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_029_Transcript.csv
# (1411, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_030_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_030_Transcript.csv
# (287, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_031_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training_031_Transcript.csv
# (445, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/training_032_densenet201.csv
# /content/drive/My Drive/AVEC_trans/training
densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_31_Transcript.csv
# (495, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_32_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_32_Transcript.csv
# (481, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_33_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_33_Transcript.csv
# (319, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_34_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_34_Transcript.csv
# (553, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_35_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_35_Transcript.csv
# (861, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_36_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_36_Transcript.csv
# (687, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_37_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_37_Transcript.csv
# (257, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_38_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_38_Transcript.csv
# (430, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_39_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_39_Transcript.csv
# (791, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_40_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_40_Transcript.csv
# (527, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_41_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_41_Transcript.csv
# (97, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_42_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_42_Transcript.csv
# (226, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_43_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_43_Transcript.csv
# (252, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_44_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_44_Transcript.csv
# (361, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_45_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_45_Transcript.csv
# (569, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_46_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_46_Transcript.csv
# (297, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_47_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_47_Transcript.csv
# (595, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_48_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_48_Transcript.csv
# (783, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_49_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_49_Transcript.csv
# (581, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_50_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_50_Transcript.csv
# (192, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_51_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_51_Transcript.csv
# (461, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_52_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_52_Transcript.csv
# (262, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_53_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_53_Transcript.csv
# (173, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_54_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_54_Transcript.csv
# (430, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_55_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_55_Transcript.csv
# (863, 1920)
# (1415, 1920)
# /content/drive/My Drive/audio_deep_features/development_56_densenet201.csv
# /content/drive/My Drive/AVEC_trans/development_56_Transcript.csv
# (244, 1920)
# (1415, 1920)

# %%
print(max(m))
# Out:
# 1411

# %%
print(len(densenet_data))
print(len(target_densenet))
densenet_data=np.asarray(densenet_data)
print(densenet_data.shape)
# Out:
# 219
# 219
# (219, 1415, 1920)

# %%
train_data,train_lbl=[],[]
pth=["/content/drive/My Drive/AVEC_trans/metadata.csv"]
for p in pth:
    with open(p,"rt") as f:
        l_data=csv.reader(f)
        for r in l_data:
          if len(r):
            if r[0] in target_densenet and ('training' in r[0]):
#               print(r[0],r[3])
#               print(embedding_matrix[train_target.index(r[0])])
              train_data.append(densenet_data[target_densenet.index(r[0])])
              train_lbl.append(int(r[3])) #change  this t0 2 for DAIC

# %%
print(train_data[1])
print(train_lbl)
train_data=np.asarray(train_data,dtype=np.float32)
train_lbl=np.asarray(train_lbl,dtype=np.float32)
train_lbl=np.reshape(train_lbl,(-1,1))
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [2.79394189e-05 3.37464444e-04 6.49892376e-04 ... 7.49966875e-02
#   6.27403021e-01 1.31433094e+00]
#  [4.21547520e-05 4.31223423e-04 9.10033123e-04 ... 2.63477743e-01
#   1.38802779e+00 1.28684640e+00]
#  [5.17541521e-05 2.80311797e-04 4.19339864e-04 ... 3.46822649e-01
#   8.70111287e-01 1.60477209e+00]]
# [4, 0, 6, 7, 4, 22, 15, 4, 21, 2, 7, 1, 2, 6, 3, 13, 5, 1, 5, 10, 2, 4, 4, 1, 12, 18, 5, 12, 10, 15, 11, 1, 7, 15, 23, 20, 5, 14, 10, 11, 18, 10, 10, 7, 7, 13, 4, 0, 20, 0, 0, 0, 19, 7, 0, 0, 13, 5, 12, 16, 1, 2, 10, 7, 15, 8, 11, 2, 14, 9, 9, 1, 7, 5, 5, 7, 7, 0, 0, 17, 2, 3, 10, 12, 0, 10, 16, 3, 7, 10, 3, 3, 10, 12, 3, 20, 5, 0, 1, 3, 1, 2, 0, 2, 1, 19, 1, 7, 1, 0, 1, 2, 9, 1, 17, 6, 3, 5, 16, 17, 9, 0, 0, 9, 0, 3, 3, 0, 3, 4, 3, 2, 1, 7, 1, 15, 2, 0, 0, 3, 2, 8, 0, 0, 4, 2, 1, 0, 10, 17, 6, 2, 2, 13, 12, 22, 18, 0, 7, 5, 0, 8, 1]

# %%
print(train_data.shape)
print(train_lbl.shape)
# Out:
# (163, 1415, 1920)
# (163, 1)

# %%
test_data,test_lbl=[],[]


with open("/content/drive/My Drive/AVEC_trans/metadata.csv","rt") as f:
  l_data=csv.reader(f)
  for r in l_data:
    if len(r):
      if r[0] in target_densenet and('development' in r[0]):
        print(r[0],r[3])
        test_data.append(densenet_data[target_densenet.index(r[0])])
        test_lbl.append(int(r[3]))   #change  this t0 2 for DAIC
test_data=np.asarray(test_data,dtype=np.float32)
test_lbl=np.asarray(test_lbl,dtype=np.float32)
test_lbl=np.reshape(test_lbl,(-1,1))
# Out:
# development_01 2
# development_02 3
# development_03 0
# development_04 8
# development_05 11
# development_06 20
# development_07 8
# development_08 5
# development_09 7
# development_10 9
# development_11 11
# development_12 16
# development_13 11
# development_14 12
# development_15 9
# development_16 9
# development_17 2
# development_18 16
# development_19 0
# development_20 17
# development_21 2
# development_22 9
# development_23 11
# development_24 0
# development_25 12
# development_26 3
# development_27 0
# development_28 6
# development_29 2
# development_30 10
# development_31 8
# development_32 0
# development_33 18
# development_34 6
# development_35 18
# development_36 4
# development_37 1
# development_38 1
# development_39 2
# development_40 4
# development_41 0
# development_42 6
# development_43 7
# development_44 1
# development_45 9
# development_46 4
# development_47 12
# development_48 3
# development_49 1
# development_50 4
# development_51 0
# development_52 3
# development_53 0
# development_54 7
# development_55 19
# development_56 0

# %%
print(test_data.shape)
print(test_lbl.shape)
print(test_lbl)
print(test_data[1])
# Out:
# (56, 1415, 1920)
# (56, 1)
# [[ 2.]
#  [ 3.]
#  [ 0.]
#  [ 8.]
#  [11.]
#  [20.]
#  [ 8.]
#  [ 5.]
#  [ 7.]
#  [ 9.]
#  [11.]
#  [16.]
#  [11.]
#  [12.]
#  [ 9.]
#  [ 9.]
#  [ 2.]
#  [16.]
#  [ 0.]
#  [17.]
#  [ 2.]
#  [ 9.]
#  [11.]
#  [ 0.]
#  [12.]
#  [ 3.]
#  [ 0.]
#  [ 6.]
#  [ 2.]
#  [10.]
#  [ 8.]
#  [ 0.]
#  [18.]
#  [ 6.]
#  [18.]
#  [ 4.]
#  [ 1.]
#  [ 1.]
#  [ 2.]
#  [ 4.]
#  [ 0.]
#  [ 6.]
#  [ 7.]
#  [ 1.]
#  [ 9.]
#  [ 4.]
#  [12.]
#  [ 3.]
#  [ 1.]
#  [ 4.]
#  [ 0.]
#  [ 3.]
#  [ 0.]
#  [ 7.]
#  [19.]
#  [ 0.]]
# [[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [5.0391958e-05 2.9292097e-04 7.4131833e-04 ... 7.4008323e-02
#   1.0825052e+00 2.1099551e+00]
#  [8.0877100e-05 3.3193905e-04 7.2283490e-04 ... 1.0265351e-01
#   1.2550195e+00 1.2360890e+00]
#  [3.3941047e-05 2.3161211e-04 1.6504612e-04 ... 2.9422781e-01
#   9.2277348e-01 6.1135274e-01]]

# %%
# bidirectional lstms
def network2(xx,dp):
  
  with tf.variable_scope('GEN'):
#     print("kp=",kp[0],kp[1])
    lstms_fw = [tf.nn.rnn_cell.LSTMCell(size,use_peepholes=True) for size in [200,200]]
    lstms_bw = [tf.nn.rnn_cell.LSTMCell(size,use_peepholes=True) for size in [200,200]]
#     print('fw',lstms_fw)
    drops_fw = [tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=1.0,variational_recurrent=False,dtype=tf.float32) for lstm in lstms_fw]
    drops_bw= [tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=1.0,variational_recurrent=False,dtype=tf.float32) for lstm in lstms_bw]

#      (output_fw, output_bw),final_state =tf.nn.bidirectional_dynamic_rnn(drops_fw,drops_bw,xx)
    lstm_output,output_fw, output_bw =tf.contrib.rnn.stack_bidirectional_dynamic_rnn(cells_fw=drops_fw,cells_bw=drops_bw,inputs=xx,dtype=tf.float32)
    print('lstm',lstm_output.shape)
#     print(output_fw)
    fs=lstm_output[:, -1]
#     fs=tf.reduce_sum(lstm_output,1)
#     context_vec,attention_wts = Attention(512).call(lstm_output,lstm_output[:,-1])
#     logits=tf.nn.dropout(fs,keep_prob=dp)
#     logits=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(logits,500)))
    logits=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(fs,500)))
#     logits= tf.nn.relu(tf.layers.dense(context_vec,112))
    logits=tf.nn.dropout(logits,keep_prob=dp)
    logits=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(logits,100)))
    logits=tf.nn.dropout(logits,keep_prob=dp)
    logits=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(logits,60)))
    logits= tf.layers.dense(logits,1)
    
    return logits

# %%
path = "/content/drive/My Drive/saaved_model_densenet/model.ckpt"
mm=34

# %%
tf.reset_default_graph()
batch_size=20
x=tf.placeholder(tf.float32,[None,emb_dim,1920])
y=tf.placeholder(tf.float32,[None,1])
train_phase = tf.placeholder(tf.bool, name="is_training")
drpouts= tf.placeholder(tf.float32)
logit=network2(x,drpouts)
cost=tf.reduce_mean(tf.losses.mean_squared_error(labels=y,predictions=logit))
with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
  optimizer=tf.train.AdamOptimizer(0.001).minimize(cost)
# correct_prediction = tf.equal(tf.argmax(logit,1), tf.argmax(y, 1))
# accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()
with tf.Session() as sess:
  
        saver.restore(sess,path)
        print('restored')
        los_test= sess.run(cost, feed_dict={x:test_data,y :test_lbl,drpouts:1.0,train_phase:False})
  #         los_val= sess.run(loss,feed_dict={X:val_data,Y:val_lbl,keep_prob:[1.0,1.0],drpouts:1.0,batch_size:len(val_data)})
        print("TEST LOSS FROM RESTORED MODEL AVEC : ", los_test)
  #         print("VAL ON DAIC : ", los_val)
        mm = los_test
#     sess.run(tf.global_variables_initializer())
#     for ep in range(50):   
#             sm=[]
#             train_data1,train_lbl1=shuffle(train_data,train_lbl)
#             for  j in range(train_data.shape[0]//batch_size):
#                     ls=train_data1[j*batch_size:(j*batch_size+batch_size)]
#                     otp=train_lbl1[j*batch_size:(j*batch_size+batch_size)]
                    
# #                     correct_prediction = tf.equal(tf.argmax(logit,1), tf.argmax(y, 1))
# #                     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
                    
#                     _,loss=sess.run([optimizer,cost], feed_dict={x:ls,y:otp,drpouts:1.0,train_phase:True})
#                     sm.append(loss)
#             chk=sum(sm)/len(sm)
#             print(sm)        
#             print("epoch: %d      train_loss: %f "%(ep,sum(sm)/len(sm)))
#             valid_loss= sess.run(cost, feed_dict={x:test_data,y :test_lbl,drpouts:1.0,train_phase:False})
#             print("epoch: %d      test_loss: %f "%(ep,valid_loss))
#             if (abs(chk-valid_loss)<4) and (valid_loss<mm):
#               print('SAVING..')
#               save_path = saver.save(sess, path)
#               mm=valid_loss
# Out:
# lstm (?, 1415, 400)
# W0708 20:52:02.849262 140326881437568 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# restored
# TEST LOSS FROM RESTORED MODEL AVEC :  32.002056

# %%
# test_data=np.reshape(test_data,[test_data.shape[0],test_data.shape[1],test_data.shape[2],1])
# train_data=np.reshape(train_data,[train_data.shape[0],train_data.shape[1],train_data.shape[2],1])

# %%
# def network(x,dp):
#     conv1=tf.layers.conv2d(x,kernel_size=3,strides=2,filters = 32, padding="same")
   
#     conv1=tf.nn.relu(conv1)
#     conv1=tf.layers.batch_normalization(conv1)
#     conv1=tf.nn.dropout(conv1,keep_prob=dp)
#     print(conv1.shape)
#     conv2 = tf.layers.conv2d(conv1,kernel_size=3,strides=2,filters = 64, padding="same")
    
#     conv2=tf.nn.relu(conv2)
#     conv2=tf.layers.batch_normalization(conv2)
#     conv2=tf.nn.dropout(conv2,keep_prob=dp)
#     print(conv2.shape)
#     conv3 = tf.layers.conv2d(conv2,kernel_size=3,strides=2,filters = 128, padding="same")
    
#     conv3=tf.nn.relu(conv3)
#     conv3=tf.layers.batch_normalization(conv3)
#     conv3=tf.nn.dropout(conv3,keep_prob=dp)
#     print(conv3.shape)
    
#     conv4 = tf.layers.conv2d(conv3,kernel_size=3,strides=2,filters = 128, padding="same")
    
#     conv4=tf.nn.relu(conv4)
#     conv4=tf.layers.batch_normalization(conv4)
#     conv4=tf.nn.dropout(conv4,keep_prob=dp)
#     print('conv4',conv4.shape)
    
# #     conv5 = tf.layers.conv2d(conv4,kernel_size=3,strides=2,filters = 128, padding="same")
# #     conv5=tf.nn.relu(conv5)
# #     conv5=tf.layers.batch_normalization(conv5)
# #     conv5=tf.nn.dropout(conv5,keep_prob=dp)
# #     print('conv5',conv5.shape)
    
# #     conv6 = tf.layers.conv2d(conv5,kernel_size=3,strides=2,filters = 512, padding="same")
# #     conv6=tf.nn.relu(conv6)
# #     conv6=tf.layers.batch_normalization(conv6)
# #     conv6=tf.nn.dropout(conv6,keep_prob=dp)
# #     print(conv6.shape)
#     fc=tf.reshape(conv4,[-1,89*120*128])
#     fc=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(fc,1024)))
#     fc=tf.nn.dropout(fc,keep_prob=dp)
#     fc=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(fc,512)))
#     fc=tf.nn.dropout(fc,keep_prob=dp)
#     fc=tf.layers.batch_normalization(tf.nn.relu(tf.layers.dense(fc,128)))
               
#     logit= tf.layers.dense(fc,1)
#     print(logit.shape)
#     prob=tf.nn.sigmoid(logit)
    
#     return logit,prob

# %%
# tf.reset_default_graph()
# batch_size=20
# beta=0.01
# x=tf.placeholder(tf.float32,[None,emb_dim,1920,1])
# y=tf.placeholder(tf.float32,[None,1])
# drpouts= tf.placeholder(tf.float32)
# logit,prob=network(x,drpouts)
# # variables_to_train=tf.trainable_variables()
# # regularization_cost = tf.reduce_sum([ tf.nn.l2_loss(v) for v in variables_to_train if "bias" not in v.name ])
# # cost=tf.reduce_mean(tf.reduce_mean(tf.losses.mean_squared_error(labels=y,predictions=logit)) + beta*regularization_cost)
# cost=tf.reduce_mean(tf.losses.mean_squared_error(labels=y,predictions=logit))
# with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
#   optimizer=tf.train.AdamOptimizer(0.001).minimize(cost)
# # correct_prediction = tf.equal(tf.argmax(logit,1), tf.argmax(y, 1))
# # accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# with tf.Session() as sess:
#     sess.run(tf.global_variables_initializer())
#     for ep in range(50):   
#             sm=[]
#             train_data,train_lbl=shuffle(train_data,train_lbl)
#             for  j in range(train_data.shape[0]//batch_size):
#                     ls=train_data[j*batch_size:(j*batch_size+batch_size)]
#                     otp=train_lbl[j*batch_size:(j*batch_size+batch_size)]
                    
# #                     correct_prediction = tf.equal(tf.argmax(logit,1), tf.argmax(y, 1))
# #                     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
                    
#                     _,loss=sess.run([optimizer,cost], feed_dict={x:ls,y:otp,drpouts:1.0})
#                     sm.append(loss)
#             print(sm)        
#             print("epoch: %d      train_loss: %f "%(ep,sum(sm)/len(sm)))
#             valid_loss= sess.run(cost, feed_dict={x:test_data,y :test_lbl,drpouts:1.0})
#             print("epoch: %d      test_loss: %f "%(ep,valid_loss))
